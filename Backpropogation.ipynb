# %% [markdown]
# Group members:
# 1. Rashmi Shah - 301846572
# 2. Chaitali Patil - 301877356

# %%
import numpy as np

# %%
# Sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# Derivative of sigmoid function
def sigmoid_prime(x):
    return sigmoid(x) * (1 - sigmoid(x))

# %%
# Initializing a neural network
# Input_size= no. of nodes in the input layer
# Hidden_size =  no. of nodes in the hidden layer
# Output_size = no. of nodes in the output layer
def initialize_network(input_size, hidden_size, output_size):         # Initializing the weights of a neural network with random values
    network = {                                                       # Initializing a dictionary to hold the network weights
        'weights_input_hidden': np.random.rand(hidden_size, input_size) * 0.02 - 0.01,
        'weights_hidden_output': np.random.rand(output_size, hidden_size) * 0.02 - 0.01
    }
    return network

# %%
# Forward propagate an input to calculate the output of a neural network
def forward_propagate(network, input_data):
    hidden_output = sigmoid(np.dot(network['weights_input_hidden'], input_data))
    output = sigmoid(np.dot(network['weights_hidden_output'], hidden_output))
    return output

# %%
# Performing backpropagation to update the weights of a neural network
def backpropagate(network, input_data, target_output, learning_rate):

    # Forward pass: calculating the output of the hidden layer and the final output
    hidden_output = sigmoid(np.dot(network['weights_input_hidden'], input_data))
    output = sigmoid(np.dot(network['weights_hidden_output'], hidden_output))

    # Calculating the errors for the output layer and the hidden layer
    output_error = target_output - output            # Error in the output layer
    hidden_error = np.dot(network['weights_hidden_output'].T, output_error)

    # Calculating the deltas for the output layer and the hidden layer
    delta_output = output_error * sigmoid_prime(output)         # Delta for the output layer
    delta_hidden = hidden_error * sigmoid_prime(hidden_output)          # Delta for the hidden layer

    # Updating the weights
    network['weights_hidden_output'] += learning_rate * np.outer(delta_output, hidden_output)
    network['weights_input_hidden'] += learning_rate * np.outer(delta_hidden, input_data)

# %%
# Training the network with online training
def train_network_online(network, input_data, target_output, learning_rate, epochs):
    errors = []                 # Storing errors for each epoch in lists
    accuracies = []             # Storing accuracies for each epoch in lists

    # Looping through each epoch
    for epoch in range(epochs):
        total_squared_error = 0              # Initializing total squared error for the epoch
        correct_predictions = 0              # Initializing number of correct predictions for the epoch

        # Looping through each data point in the input data
        for i in range(len(input_data)):
            backpropagate(network, input_data[i], target_output[i], learning_rate)       # Performing backpropagation to update weights
            prediction = forward_propagate(network, input_data[i])[0]           # Forward propagation to make predictions
            total_squared_error += (target_output[i] - prediction) ** 2          # Calculating total squared error

            # Checking for correct predictions
            if round(prediction) == target_output[i]:
                correct_predictions += 1
        errors.append(total_squared_error)                             # Calculating and storing total squared error and accuracy for the epoch
        accuracies.append(correct_predictions / len(input_data))
        print(f"Epoch {epoch+1}: Error = {total_squared_error}, Accuracy = {accuracies[-1]}")
    return errors, accuracies                                          # Returning lists of errors and accuracies for all epochs

# %%
# Training the network with batch training
def train_network_batch(network, input_data, target_output, learning_rate, epochs):

    # Storing errors and accuracies for each epoch in lists
    errors = []
    accuracies = []

     # Looping through each epoch
    for epoch in range(epochs):
        total_squared_error = 0      # Total squared error for the epoch
        correct_predictions = 0      # Number of correct predictions for the epoch

        # Initializing delta arrays for weights update
        delta_output_batch = np.zeros_like(network['weights_hidden_output'])
        delta_hidden_batch = np.zeros_like(network['weights_input_hidden'])

        # Looping through each data point in the input data
        for i in range(len(input_data)):

            # Forward pass
            hidden_output = sigmoid(np.dot(network['weights_input_hidden'], input_data[i]))
            output = sigmoid(np.dot(network['weights_hidden_output'], hidden_output))

            # Calculating Error
            output_error = target_output[i] - output
            hidden_error = np.dot(network['weights_hidden_output'].T, output_error)

            # Backpropagation - Calculating deltas
            delta_output = output_error * sigmoid_prime(output)
            delta_hidden = hidden_error * sigmoid_prime(hidden_output)

            # Accumulating deltas for batch update
            delta_output_batch += np.outer(delta_output, hidden_output)
            delta_hidden_batch += np.outer(delta_hidden, input_data[i])

            # Calculating total squared error
            prediction = output[0]
            total_squared_error += (target_output[i] - prediction) ** 2

            # Checking for correct predictions
            if round(prediction) == target_output[i]:
                correct_predictions += 1

        # Updating weights using averaged deltas
        network['weights_hidden_output'] += learning_rate * delta_output_batch / len(input_data)
        network['weights_input_hidden'] += learning_rate * delta_hidden_batch / len(input_data)

        # Calculating and storing mean squared error and accuracy for the epoch
        errors.append(total_squared_error)
        accuracies.append(correct_predictions / len(input_data))

        print(f"Epoch {epoch+1}: Error = {total_squared_error}, Accuracy = {accuracies[-1]}")     # Printing epoch information
    return errors, accuracies           # Returning lists of errors and accuracies for all epochs

# %%
# Providing data for training
input_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
target_output = np.array([[0], [1], [1], [0]])

# %%
# Learning Experiment with Online Training : 5 times results for the experiment
print("Learning Experiment with Online Training:")

# Looping through 5 experiments
for i in range(5):
    print(f"\nExperiment {i+1}:")           # Printing experiment number
    network = initialize_network(input_size=2, hidden_size=4, output_size=1)            # Initializing a neural network for the experiment

    # Printing initial random weights
    print("Initial Random Weights:")
    print("weights_input_hidden:", network['weights_input_hidden'])
    print("weights_hidden_output:", network['weights_hidden_output'])

    # Training the network using online training
    errors, accuracies = train_network_online(network, input_data, target_output, learning_rate=0.1, epochs=20)

    # Printing final weights after training
    print("Final Weights:")
    print("weights_input_hidden:", network['weights_input_hidden'])
    print("weights_hidden_output:", network['weights_hidden_output'])

    # Printing final weights after training
    print("Squared Error at the end of training:", errors[-1])
    print("Accuracy at the end of training:", accuracies[-1])
# Out:
# Learning Experiment with Online Training:
#
# Experiment 1:
# Initial Random Weights:
# weights_input_hidden: [[-0.00913287 -0.0083436 ]
#  [-0.00898382  0.00012817]
#  [ 0.0018989  -0.00495245]
#  [ 0.00397387 -0.0081923 ]]
# weights_hidden_output: [[-0.0046866   0.0007801   0.00611664  0.00810037]]
# Epoch 1: Error = [0.99414076], Accuracy = 0.75
# Epoch 2: Error = [0.99414108], Accuracy = 0.75
# Epoch 3: Error = [0.99414142], Accuracy = 0.75
# Epoch 4: Error = [0.99414177], Accuracy = 0.75
# Epoch 5: Error = [0.99414213], Accuracy = 0.75
# Epoch 6: Error = [0.9941425], Accuracy = 0.75
# Epoch 7: Error = [0.99414288], Accuracy = 0.75
# Epoch 8: Error = [0.99414327], Accuracy = 0.75
# Epoch 9: Error = [0.99414367], Accuracy = 0.75
# Epoch 10: Error = [0.99414407], Accuracy = 0.75
# Epoch 11: Error = [0.99414449], Accuracy = 0.75
# Epoch 12: Error = [0.99414491], Accuracy = 0.75
# Epoch 13: Error = [0.99414534], Accuracy = 0.75
# Epoch 14: Error = [0.99414578], Accuracy = 0.75
# Epoch 15: Error = [0.99414623], Accuracy = 0.75
# Epoch 16: Error = [0.99414668], Accuracy = 0.75
# Epoch 17: Error = [0.99414714], Accuracy = 0.75
# Epoch 18: Error = [0.9941476], Accuracy = 0.75
# Epoch 19: Error = [0.99414807], Accuracy = 0.75
# Epoch 20: Error = [0.99414855], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[-0.01050314 -0.01110665]
#  [-0.01036725 -0.00264568]
#  [ 0.00049527 -0.00773538]
#  [ 0.00256348 -0.01097648]]
# weights_hidden_output: [[-5.50310648e-03 -4.54770521e-05  5.27849039e-03  7.25886579e-03]]
# Squared Error at the end of training: [0.99414855]
# Accuracy at the end of training: 0.75
#
# Experiment 2:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00722265 -0.00302513]
#  [ 0.00302841  0.0073931 ]
#  [ 0.00890031  0.00372118]
#  [ 0.00587504 -0.00991892]]
# weights_hidden_output: [[-0.00424657  0.00678188 -0.00140236  0.00097429]]
# Epoch 1: Error = [0.99409122], Accuracy = 0.75
# Epoch 2: Error = [0.99409184], Accuracy = 0.75
# Epoch 3: Error = [0.99409245], Accuracy = 0.75
# Epoch 4: Error = [0.99409307], Accuracy = 0.75
# Epoch 5: Error = [0.99409368], Accuracy = 0.75
# Epoch 6: Error = [0.9940943], Accuracy = 0.75
# Epoch 7: Error = [0.99409491], Accuracy = 0.75
# Epoch 8: Error = [0.99409553], Accuracy = 0.75
# Epoch 9: Error = [0.99409614], Accuracy = 0.75
# Epoch 10: Error = [0.99409676], Accuracy = 0.75
# Epoch 11: Error = [0.99409737], Accuracy = 0.75
# Epoch 12: Error = [0.99409799], Accuracy = 0.75
# Epoch 13: Error = [0.9940986], Accuracy = 0.75
# Epoch 14: Error = [0.99409922], Accuracy = 0.75
# Epoch 15: Error = [0.99409984], Accuracy = 0.75
# Epoch 16: Error = [0.99410045], Accuracy = 0.75
# Epoch 17: Error = [0.99410107], Accuracy = 0.75
# Epoch 18: Error = [0.99410168], Accuracy = 0.75
# Epoch 19: Error = [0.9941023], Accuracy = 0.75
# Epoch 20: Error = [0.99410292], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[ 0.00583676 -0.00581139]
#  [ 0.0016283   0.00460184]
#  [ 0.00750899  0.00092987]
#  [ 0.00448049 -0.01270152]]
# weights_hidden_output: [[-0.00430972  0.00670515 -0.00146993  0.00090422]]
# Squared Error at the end of training: [0.99410292]
# Accuracy at the end of training: 0.75
#
# Experiment 3:
# Initial Random Weights:
# weights_input_hidden: [[-0.00890278  0.00720132]
#  [-0.00840074 -0.00264952]
#  [ 0.00193816  0.00237013]
#  [ 0.00836136 -0.00027564]]
# weights_hidden_output: [[ 0.00727579  0.00499478  0.0002826  -0.00721361]]
# Epoch 1: Error = [0.99411044], Accuracy = 0.75
# Epoch 2: Error = [0.99411099], Accuracy = 0.75
# Epoch 3: Error = [0.99411154], Accuracy = 0.75
# Epoch 4: Error = [0.99411209], Accuracy = 0.75
# Epoch 5: Error = [0.99411264], Accuracy = 0.75
# Epoch 6: Error = [0.9941132], Accuracy = 0.75
# Epoch 7: Error = [0.99411376], Accuracy = 0.75
# Epoch 8: Error = [0.99411432], Accuracy = 0.75
# Epoch 9: Error = [0.99411488], Accuracy = 0.75
# Epoch 10: Error = [0.99411544], Accuracy = 0.75
# Epoch 11: Error = [0.99411601], Accuracy = 0.75
# Epoch 12: Error = [0.99411658], Accuracy = 0.75
# Epoch 13: Error = [0.99411715], Accuracy = 0.75
# Epoch 14: Error = [0.99411772], Accuracy = 0.75
# Epoch 15: Error = [0.99411829], Accuracy = 0.75
# Epoch 16: Error = [0.99411887], Accuracy = 0.75
# Epoch 17: Error = [0.99411944], Accuracy = 0.75
# Epoch 18: Error = [0.99412002], Accuracy = 0.75
# Epoch 19: Error = [0.9941206], Accuracy = 0.75
# Epoch 20: Error = [0.99412118], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[-0.01029807  0.00441614]
#  [-0.00979362 -0.00542822]
#  [ 0.00054868 -0.00041439]
#  [ 0.0069823  -0.00305948]]
# weights_hidden_output: [[ 6.90579605e-03  4.62822594e-03 -8.21598971e-05 -7.57062282e-03]]
# Squared Error at the end of training: [0.99412118]
# Accuracy at the end of training: 0.75
#
# Experiment 4:
# Initial Random Weights:
# weights_input_hidden: [[-0.00566308  0.00032223]
#  [ 0.00287034  0.00589277]
#  [ 0.00827391  0.00354886]
#  [ 0.0008231  -0.00134438]]
# weights_hidden_output: [[-0.00881347  0.00534232 -0.00522314  0.00264125]]
# Epoch 1: Error = [0.99409789], Accuracy = 0.75
# Epoch 2: Error = [0.99409841], Accuracy = 0.75
# Epoch 3: Error = [0.99409894], Accuracy = 0.75
# Epoch 4: Error = [0.99409948], Accuracy = 0.75
# Epoch 5: Error = [0.99410002], Accuracy = 0.75
# Epoch 6: Error = [0.99410057], Accuracy = 0.75
# Epoch 7: Error = [0.99410112], Accuracy = 0.75
# Epoch 8: Error = [0.99410168], Accuracy = 0.75
# Epoch 9: Error = [0.99410224], Accuracy = 0.75
# Epoch 10: Error = [0.9941028], Accuracy = 0.75
# Epoch 11: Error = [0.99410337], Accuracy = 0.75
# Epoch 12: Error = [0.99410394], Accuracy = 0.75
# Epoch 13: Error = [0.99410451], Accuracy = 0.75
# Epoch 14: Error = [0.99410509], Accuracy = 0.75
# Epoch 15: Error = [0.99410567], Accuracy = 0.75
# Epoch 16: Error = [0.99410625], Accuracy = 0.75
# Epoch 17: Error = [0.99410684], Accuracy = 0.75
# Epoch 18: Error = [0.99410743], Accuracy = 0.75
# Epoch 19: Error = [0.99410802], Accuracy = 0.75
# Epoch 20: Error = [0.99410861], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[-0.00704088 -0.00246734]
#  [ 0.00147575  0.00310187]
#  [ 0.00688446  0.00074967]
#  [-0.00056901 -0.00413181]]
# weights_hidden_output: [[-0.00810111  0.0060347  -0.00451752  0.00333619]]
# Squared Error at the end of training: [0.99410861]
# Accuracy at the end of training: 0.75
#
# Experiment 5:
# Initial Random Weights:
# weights_input_hidden: [[-0.0053589  -0.00543527]
#  [ 0.0039102  -0.00837664]
#  [-0.00775746  0.00777151]
#  [ 0.00478176  0.00236947]]
# weights_hidden_output: [[-0.00099118 -0.00884806  0.00152531 -0.00352093]]
# Epoch 1: Error = [0.99412021], Accuracy = 0.75
# Epoch 2: Error = [0.99412045], Accuracy = 0.75
# Epoch 3: Error = [0.9941207], Accuracy = 0.75
# Epoch 4: Error = [0.99412097], Accuracy = 0.75
# Epoch 5: Error = [0.99412127], Accuracy = 0.75
# Epoch 6: Error = [0.99412157], Accuracy = 0.75
# Epoch 7: Error = [0.9941219], Accuracy = 0.75
# Epoch 8: Error = [0.99412224], Accuracy = 0.75
# Epoch 9: Error = [0.9941226], Accuracy = 0.75
# Epoch 10: Error = [0.99412297], Accuracy = 0.75
# Epoch 11: Error = [0.99412335], Accuracy = 0.75
# Epoch 12: Error = [0.99412375], Accuracy = 0.75
# Epoch 13: Error = [0.99412416], Accuracy = 0.75
# Epoch 14: Error = [0.99412458], Accuracy = 0.75
# Epoch 15: Error = [0.99412501], Accuracy = 0.75
# Epoch 16: Error = [0.99412545], Accuracy = 0.75
# Epoch 17: Error = [0.9941259], Accuracy = 0.75
# Epoch 18: Error = [0.99412636], Accuracy = 0.75
# Epoch 19: Error = [0.99412683], Accuracy = 0.75
# Epoch 20: Error = [0.99412731], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[-0.00674493 -0.00822225]
#  [ 0.00252189 -0.0111765 ]
#  [-0.00914155  0.0049814 ]
#  [ 0.00339093 -0.00043071]]
# weights_hidden_output: [[ 0.00025309 -0.00759422  0.00277079 -0.00227078]]
# Squared Error at the end of training: [0.99412731]
# Accuracy at the end of training: 0.75

# %%
# Learning Experiment with Batch Training: 5 times results for the experiment
print("\nLearning Experiment with Batch Training:")

# Looping through 5 experiments
for i in range(5):
    print(f"\nExperiment {i+1}:")                 # Printing experiment number

    network = initialize_network(input_size=2, hidden_size=4, output_size=1)               # Initializing a neural network for the experiment

     # Printing initial random weights
    print("Initial Random Weights:")
    print("weights_input_hidden:", network['weights_input_hidden'])
    print("weights_hidden_output:", network['weights_hidden_output'])

    # Training the network using batch training
    errors, accuracies = train_network_batch(network, input_data, target_output, learning_rate=0.1, epochs=20)

    # Printing final weights after training
    print("Final Weights:")
    print("weights_input_hidden:", network['weights_input_hidden'])
    print("weights_hidden_output:", network['weights_hidden_output'])

    # Printing squared error and accuracy at the end of training
    print("Squared Error at the end of training:", errors[-1])
    print("Accuracy at the end of training:", accuracies[-1])
# Out:
# Learning Experiment with Batch Training:
#
# Experiment 1:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00257362  0.00101479]
#  [ 0.00153814  0.00071813]
#  [ 0.00091264  0.00661414]
#  [ 0.00665836 -0.00434685]]
# weights_hidden_output: [[0.00162966 0.0083391  0.00918698 0.00861599]]
# Epoch 1: Error = [1.0000483], Accuracy = 0.5
# Epoch 2: Error = [1.00004774], Accuracy = 0.5
# Epoch 3: Error = [1.00004718], Accuracy = 0.5
# Epoch 4: Error = [1.00004662], Accuracy = 0.5
# Epoch 5: Error = [1.00004608], Accuracy = 0.5
# Epoch 6: Error = [1.00004553], Accuracy = 0.5
# Epoch 7: Error = [1.000045], Accuracy = 0.5
# Epoch 8: Error = [1.00004447], Accuracy = 0.5
# Epoch 9: Error = [1.00004395], Accuracy = 0.5
# Epoch 10: Error = [1.00004344], Accuracy = 0.5
# Epoch 11: Error = [1.00004293], Accuracy = 0.5
# Epoch 12: Error = [1.00004242], Accuracy = 0.5
# Epoch 13: Error = [1.00004193], Accuracy = 0.5
# Epoch 14: Error = [1.00004143], Accuracy = 0.5
# Epoch 15: Error = [1.00004095], Accuracy = 0.5
# Epoch 16: Error = [1.00004047], Accuracy = 0.5
# Epoch 17: Error = [1.00003999], Accuracy = 0.5
# Epoch 18: Error = [1.00003952], Accuracy = 0.5
# Epoch 19: Error = [1.00003906], Accuracy = 0.5
# Epoch 20: Error = [1.0000386], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[ 0.00257265  0.00101382]
#  [ 0.001532    0.00071201]
#  [ 0.00090603  0.00660736]
#  [ 0.00665185 -0.00435303]]
# weights_hidden_output: [[0.00085702 0.00756672 0.00841359 0.0078436 ]]
# Squared Error at the end of training: [1.0000386]
# Accuracy at the end of training: 0.5
#
# Experiment 2:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00187795  0.00754337]
#  [-0.0083693  -0.00533895]
#  [-0.00233577 -0.00734513]
#  [ 0.00856878  0.00918992]]
# weights_hidden_output: [[-0.0045955   0.00918844  0.00649863 -0.00312245]]
# Epoch 1: Error = [1.0000039], Accuracy = 0.5
# Epoch 2: Error = [1.00000385], Accuracy = 0.5
# Epoch 3: Error = [1.00000381], Accuracy = 0.5
# Epoch 4: Error = [1.00000376], Accuracy = 0.5
# Epoch 5: Error = [1.00000372], Accuracy = 0.5
# Epoch 6: Error = [1.00000368], Accuracy = 0.5
# Epoch 7: Error = [1.00000363], Accuracy = 0.5
# Epoch 8: Error = [1.00000359], Accuracy = 0.5
# Epoch 9: Error = [1.00000355], Accuracy = 0.5
# Epoch 10: Error = [1.00000351], Accuracy = 0.5
# Epoch 11: Error = [1.00000346], Accuracy = 0.5
# Epoch 12: Error = [1.00000342], Accuracy = 0.5
# Epoch 13: Error = [1.00000338], Accuracy = 0.5
# Epoch 14: Error = [1.00000334], Accuracy = 0.5
# Epoch 15: Error = [1.00000331], Accuracy = 0.5
# Epoch 16: Error = [1.00000327], Accuracy = 0.5
# Epoch 17: Error = [1.00000323], Accuracy = 0.5
# Epoch 18: Error = [1.00000319], Accuracy = 0.5
# Epoch 19: Error = [1.00000315], Accuracy = 0.5
# Epoch 20: Error = [1.00000312], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[ 0.00187885  0.00754436]
#  [-0.00837146 -0.00534121]
#  [-0.00233733 -0.00734658]
#  [ 0.00856938  0.00919053]]
# weights_hidden_output: [[-0.00481544  0.00896976  0.00627973 -0.00334285]]
# Squared Error at the end of training: [1.00000312]
# Accuracy at the end of training: 0.5
#
# Experiment 3:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00059127 -0.00192947]
#  [ 0.00036684 -0.00583272]
#  [ 0.00641109 -0.00915461]
#  [-0.00425427 -0.00611565]]
# weights_hidden_output: [[ 0.00201225 -0.00932134  0.00818299  0.00844362]]
# Epoch 1: Error = [1.00000541], Accuracy = 0.5
# Epoch 2: Error = [1.00000534], Accuracy = 0.5
# Epoch 3: Error = [1.00000528], Accuracy = 0.5
# Epoch 4: Error = [1.00000522], Accuracy = 0.5
# Epoch 5: Error = [1.00000516], Accuracy = 0.5
# Epoch 6: Error = [1.0000051], Accuracy = 0.5
# Epoch 7: Error = [1.00000504], Accuracy = 0.5
# Epoch 8: Error = [1.00000498], Accuracy = 0.5
# Epoch 9: Error = [1.00000492], Accuracy = 0.5
# Epoch 10: Error = [1.00000487], Accuracy = 0.5
# Epoch 11: Error = [1.00000481], Accuracy = 0.5
# Epoch 12: Error = [1.00000475], Accuracy = 0.5
# Epoch 13: Error = [1.0000047], Accuracy = 0.5
# Epoch 14: Error = [1.00000464], Accuracy = 0.5
# Epoch 15: Error = [1.00000459], Accuracy = 0.5
# Epoch 16: Error = [1.00000453], Accuracy = 0.5
# Epoch 17: Error = [1.00000448], Accuracy = 0.5
# Epoch 18: Error = [1.00000443], Accuracy = 0.5
# Epoch 19: Error = [1.00000438], Accuracy = 0.5
# Epoch 20: Error = [1.00000433], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[ 0.00059077 -0.00192995]
#  [ 0.00036948 -0.0058303 ]
#  [ 0.00640874 -0.0091565 ]
#  [-0.00425661 -0.00611793]]
# weights_hidden_output: [[ 0.00175384 -0.00957948  0.00792467  0.00818579]]
# Squared Error at the end of training: [1.00000433]
# Accuracy at the end of training: 0.5
#
# Experiment 4:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00623759  0.00839396]
#  [ 0.00060742  0.00615543]
#  [-0.00754687 -0.00331618]
#  [-0.00655938  0.00616989]]
# weights_hidden_output: [[-0.00616223 -0.00385258 -0.00196376 -0.00777353]]
# Epoch 1: Error = [1.00002444], Accuracy = 0.5
# Epoch 2: Error = [1.00002415], Accuracy = 0.5
# Epoch 3: Error = [1.00002387], Accuracy = 0.5
# Epoch 4: Error = [1.00002359], Accuracy = 0.5
# Epoch 5: Error = [1.00002331], Accuracy = 0.5
# Epoch 6: Error = [1.00002304], Accuracy = 0.5
# Epoch 7: Error = [1.00002277], Accuracy = 0.5
# Epoch 8: Error = [1.0000225], Accuracy = 0.5
# Epoch 9: Error = [1.00002224], Accuracy = 0.5
# Epoch 10: Error = [1.00002198], Accuracy = 0.5
# Epoch 11: Error = [1.00002172], Accuracy = 0.5
# Epoch 12: Error = [1.00002146], Accuracy = 0.5
# Epoch 13: Error = [1.00002121], Accuracy = 0.5
# Epoch 14: Error = [1.00002096], Accuracy = 0.5
# Epoch 15: Error = [1.00002072], Accuracy = 0.5
# Epoch 16: Error = [1.00002047], Accuracy = 0.5
# Epoch 17: Error = [1.00002023], Accuracy = 0.5
# Epoch 18: Error = [1.00002], Accuracy = 0.5
# Epoch 19: Error = [1.00001976], Accuracy = 0.5
# Epoch 20: Error = [1.00001953], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[ 0.00623417  0.00839059]
#  [ 0.00060536  0.00615345]
#  [-0.00754778 -0.00331708]
#  [-0.00656368  0.00616593]]
# weights_hidden_output: [[-0.00561037 -0.0033018  -0.00141541 -0.00722373]]
# Squared Error at the end of training: [1.00001953]
# Accuracy at the end of training: 0.5
#
# Experiment 5:
# Initial Random Weights:
# weights_input_hidden: [[-0.0010456  -0.00533237]
#  [-0.00911311 -0.00050662]
#  [-0.00069844  0.00125384]
#  [ 0.00409079 -0.00904174]]
# weights_hidden_output: [[ 0.0045032   0.00453312 -0.00914259 -0.00101193]]
# Epoch 1: Error = [1.00000008], Accuracy = 0.5
# Epoch 2: Error = [1.00000008], Accuracy = 0.5
# Epoch 3: Error = [1.00000008], Accuracy = 0.5
# Epoch 4: Error = [1.00000008], Accuracy = 0.5
# Epoch 5: Error = [1.00000008], Accuracy = 0.5
# Epoch 6: Error = [1.00000008], Accuracy = 0.5
# Epoch 7: Error = [1.00000008], Accuracy = 0.5
# Epoch 8: Error = [1.00000007], Accuracy = 0.5
# Epoch 9: Error = [1.00000007], Accuracy = 0.5
# Epoch 10: Error = [1.00000007], Accuracy = 0.5
# Epoch 11: Error = [1.00000007], Accuracy = 0.5
# Epoch 12: Error = [1.00000007], Accuracy = 0.5
# Epoch 13: Error = [1.00000007], Accuracy = 0.5
# Epoch 14: Error = [1.00000007], Accuracy = 0.5
# Epoch 15: Error = [1.00000007], Accuracy = 0.5
# Epoch 16: Error = [1.00000007], Accuracy = 0.5
# Epoch 17: Error = [1.00000007], Accuracy = 0.5
# Epoch 18: Error = [1.00000007], Accuracy = 0.5
# Epoch 19: Error = [1.00000007], Accuracy = 0.5
# Epoch 20: Error = [1.00000006], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[-0.00104554 -0.00533225]
#  [-0.00911297 -0.00050662]
#  [-0.00069878  0.00125358]
#  [ 0.00409079 -0.00904179]]
# weights_hidden_output: [[ 0.00453474  0.00456463 -0.009111   -0.00098038]]
# Squared Error at the end of training: [1.00000006]
# Accuracy at the end of training: 0.5
